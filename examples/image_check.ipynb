# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
src_img = cv2.imread('/home/stephen/ros_ws/src/private_visual_foresight/experiments/sawyer/offline_rl_tool/galar/train/collection_started_Jun_10_2021_20:51:32/traj0/images0/im_1.jpg')
dst_img = cv2.imread('/nfs/kun1/users/asap7772/cog/examples/dataset_img.jpg')

# %%
print(src_img.shape)
print(dst_img.shape)
# Out:
# (64, 64, 3)
# (64, 64, 3)

# %%
plt.imshow(src_img[:,:,::-1])

# %%
plt.imshow(dst_img[:,:,::-1])

# %%
matrix = np.load('/nfs/kun1/users/asap7772/cog/examples/mat_curr2dataset.npy', allow_pickle=True)
warped = cv2.warpPerspective(src_img, matrix, (dst_img.shape[1], dst_img.shape[0]))
plt.imshow(warped[:,:,::-1])
